# %%
import pandas as pd

# %% [markdown]
# #### Series

# %%
s1 = pd.Series([56,32,12,36,58,79])

# %%
s1
# Out:
# 0    56
# 1    32
# 2    12
# 3    36
# 4    58
# 5    79
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1[4]
# Out:
# 58

# %%
s1[4] = 57

# %%
s1
# Out:
# 0    56
# 1    32
# 2    12
# 3    36
# 4    57
# 5    79
# dtype: int64

# %%
s1.max()
# Out:
# 79

# %%
s1.values
# Out:
# array([56, 32, 12, 36, 57, 79])

# %%
s1 / 5
# Out:
# 0    11.2
# 1     6.4
# 2     2.4
# 3     7.2
# 4    11.4
# 5    15.8
# dtype: float64

# %% [markdown]
# #### DataFrame

# %%
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series(['Kiran','Harshal','Ravi','Priya','Asha'])
s3 = pd.Series([56.78, 89.67, 74.65, 82.34, 65.33])

# %%
df = pd.DataFrame({
    'roll': s1,
    'name': s2,
    'marks': s3
})

# %%
df
# Out:
#    roll     name  marks
# 0     1    Kiran  56.78
# 1     2  Harshal  89.67
# 2     3     Ravi  74.65
# 3     4    Priya  82.34
# 4     5     Asha  65.33

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (5, 3)

# %%
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series(['Kiran','Harshal','Ravi','Priya','Asha'])
s3 = pd.Series([56.78, 89.67, 74.65, 82.34])
df1 = pd.DataFrame({
    'roll': s1,
    'name': s2,
    'marks': s3
})
df1
# Out:
#    roll     name  marks
# 0     1    Kiran  56.78
# 1     2  Harshal  89.67
# 2     3     Ravi  74.65
# 3     4    Priya  82.34
# 4     5     Asha    NaN
