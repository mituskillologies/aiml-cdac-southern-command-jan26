# %% [markdown]
# #### Import the libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from keras.models import Sequential
from keras.layers import Dense, Input 
from keras.utils import to_categorical, plot_model
from keras.datasets import mnist

# %% [markdown]
# #### Load the data

# %%
(x_train, y_train),(x_test, y_test) = mnist.load_data()

# %% [markdown]
# #### Feature Scaling

# %%
x_train = x_train / 255
x_test = x_test / 255

# %% [markdown]
# #### Build the model

# %%
from keras.layers import Conv2D, MaxPool2D, Flatten

# %%
model = Sequential()

model.add(Input((28,28,1)))
model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=16, kernel_size=(3,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# #### Compile the model

# %%
model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# #### Train the model

# %%
model.fit(x_train, y_train, epochs=10, batch_size=10)
# Out:
# Epoch 1/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - accuracy: 0.9165 - loss: 0.2663
# Epoch 2/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - accuracy: 0.9850 - loss: 0.0483
# Epoch 3/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.9905 - loss: 0.0303
# Epoch 4/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.9924 - loss: 0.0238
# Epoch 5/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.9940 - loss: 0.0178
# Epoch 6/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.9945 - loss: 0.0157
# Epoch 7/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.9956 - loss: 0.0131
# Epoch 8/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.9964 - loss: 0.0119
# Epoch 9/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.9970 - loss: 0.0089
# Epoch 10/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.9967 - loss: 0.0093

# %% [markdown]
# #### Evaluate on test data

# %%
model.evaluate(x_test, y_test, batch_size=1)
# Out:
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - accuracy: 0.9870 - loss: 0.0625
# [0.046068303287029266, 0.9904999732971191]

# %% [markdown]
# #### Predict on unseen data

# %%
import cv2

# %%
newchar = cv2.imread('new-char1.jpg', 0)  # read 
newchar = cv2.resize(newchar,(28,28))  # resize
newchar = newchar.reshape(1,28,28)
thresh, newchar = cv2.threshold(newchar, 128, 255, cv2.THRESH_BINARY_INV)
newchar = newchar / 255             # scale
result = model.predict(newchar, verbose=False)  # predict
result.argmax()
# Out:
# 5
