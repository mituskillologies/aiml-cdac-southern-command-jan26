# %%
from keras.applications.resnet50 import ResNet50, preprocess_input
from keras.applications.resnet50 import decode_predictions
from keras.preprocessing.image import load_img, img_to_array
import urllib, PIL, cv2
import numpy as np

# %%
model = ResNet50()
# Out:
# 2026-01-21 11:38:52.771274: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
img = load_img('dog.jpg')

# %%
img_array = img_to_array(img)
img_array = cv2.resize(img_array, (224,224))
# preprocess the input 
img_pre = preprocess_input(img_array)
# reshape the image 
img_pre = img_pre.reshape(1,224,224,3)
# predict the class 
result = model.predict(img_pre, verbose=False)

# %%
predictions = decode_predictions(result)
predictions[0][0][1]
# Out:
# 'golden_retriever'
