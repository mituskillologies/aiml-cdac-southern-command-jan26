# %%
# https://mitu.co.in/dataset 
# Dataset: Social_Network_Ads.csv

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
x = df[['Age','EstimatedSalary']]

# %%
plt.title("Purchasing Details")
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid()
plt.scatter(x['Age'], x['EstimatedSalary'], c = df['Purchased'])

# %%
df['Age']
# Out:
# 0      19.0
# 1      35.0
# 2      26.0
# 3      27.0
# 4      19.0
#        ...
# 395    46.0
# 396    51.0
# 397    50.0
# 398    36.0
# 399    49.0
# Name: Age, Length: 400, dtype: float64

# %%
new = (df['Age'] - df['Age'].min()) / (df['Age'].max() - df['Age'].min())

# %%
new
# Out:
# 0      0.023810
# 1      0.404762
# 2      0.190476
# 3      0.214286
# 4      0.023810
#          ...
# 395    0.666667
# 396    0.785714
# 397    0.761905
# 398    0.428571
# 399    0.738095
# Name: Age, Length: 400, dtype: float64

# %%
new.min()
# Out:
# 0.0

# %%
new.max()
# Out:
# 1.0

# %%
new1 = (df['EstimatedSalary'] - df['EstimatedSalary'].min()) / (df['EstimatedSalary'].max() - df['EstimatedSalary'].min())

# %%
new1.min(),new1.max()
# Out:
# (0.0, 1.0)

# %%
plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.title("Original Data")
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid()
plt.scatter(x['Age'], x['EstimatedSalary'], c = df['Purchased'])

plt.subplot(1,2,2)
plt.title("Scaled Data")
plt.scatter(new, new1, c = df['Purchased'])

# %%
# import the class
from sklearn.preprocessing import MinMaxScaler

# %%
# create the object
scaler = MinMaxScaler()

# %%
# apply the steps 
x_new = scaler.fit_transform(x)

# %%
x_new
# Out:
# array([[0.02380952, 0.02962963],
#        [0.4047619 , 0.03703704],
#        [0.19047619, 0.20740741],
#        [0.21428571, 0.31111111],
#        [0.02380952, 0.45185185],
#        [0.21428571, 0.31851852],
#        [0.21428571, 0.51111111],
#        [0.33333333, 1.        ],
#        [0.16666667, 0.13333333],
#        [0.4047619 , 0.37037037],
#        [0.19047619, 0.48148148],
#        [0.19047619, 0.27407407],
#        [0.04761905, 0.52592593],
#        [0.33333333, 0.02222222],
#        [0.        , 0.4962963 ],
#        [0.26190476, 0.48148148],
#        [0.69047619, 0.07407407],
#        [0.64285714, 0.08148148],
#        [0.66666667, 0.0962963 ],
#        [0.71428571, 0.1037037 ],
#        [0.64285714, 0.05185185],
#        [0.69047619, 0.25185185],
#        [0.71428571, 0.19259259],
#        [0.64285714, 0.05185185],
#        [0.66666667, 0.05925926],
#        [0.69047619, 0.03703704],
#        [0.73809524, 0.0962963 ],
#        [0.69047619, 0.11111111],
# ...

# %%
df_new = pd.DataFrame(x_new, columns=x.columns)

# %%
df_new
# Out:
#           Age  EstimatedSalary
# 0    0.023810         0.029630
# 1    0.404762         0.037037
# 2    0.190476         0.207407
# 3    0.214286         0.311111
# 4    0.023810         0.451852
# ..        ...              ...
# 395  0.666667         0.192593
# 396  0.785714         0.059259
# 397  0.761905         0.037037
# 398  0.428571         0.133333
# 399  0.738095         0.155556
#
# [400 rows x 2 columns]

# %% [markdown]
# #### Standardization

# %%
age1 = (x['Age'] - x['Age'].mean()) / x['Age'].std()

# %%
age1;

# %%
age1.std()
# Out:
# 1.0

# %%
sal1 = (x['EstimatedSalary'] - x['EstimatedSalary'].mean()) / x['EstimatedSalary'].std()

# %%
sal1.std()
# Out:
# 0.9999999999999999

# %%
x['Age'].std()
# Out:
# 10.482876597307914

# %%
x['EstimatedSalary'].std()
# Out:
# 34096.960282424785

# %%
plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.title("Original Data")
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid()
plt.scatter(x['Age'], x['EstimatedSalary'], c = df['Purchased'])

plt.subplot(1,2,2)
plt.title("Scaled Data")
plt.scatter(age1, sal1, c = df['Purchased'])

# %%
# import the class 
from sklearn.preprocessing import StandardScaler

# %%
# create the object 
scaler = StandardScaler()

# %%
# apply the scaling 
x_new = scaler.fit_transform(x)

# %%
x_new
# Out:
# array([[-1.78179743, -1.49004624],
#        [-0.25358736, -1.46068138],
#        [-1.11320552, -0.78528968],
#        [-1.01769239, -0.37418169],
#        [-1.78179743,  0.18375059],
#        [-1.01769239, -0.34481683],
#        [-1.01769239,  0.41866944],
#        [-0.54012675,  2.35674998],
#        [-1.20871865, -1.07893824],
#        [-0.25358736, -0.13926283],
#        [-1.11320552,  0.30121002],
#        [-1.11320552, -0.52100597],
#        [-1.6862843 ,  0.47739916],
#        [-0.54012675, -1.51941109],
#        [-1.87731056,  0.35993973],
#        [-0.82666613,  0.30121002],
#        [ 0.89257019, -1.3138571 ],
#        [ 0.70154394, -1.28449224],
#        [ 0.79705706, -1.22576253],
#        [ 0.98808332, -1.19639767],
#        [ 0.70154394, -1.40195167],
#        [ 0.89257019, -0.60910054],
#        [ 0.98808332, -0.84401939],
#        [ 0.70154394, -1.40195167],
#        [ 0.79705706, -1.37258681],
#        [ 0.89257019, -1.46068138],
#        [ 1.08359645, -1.22576253],
# ...

# %%
df_new = pd.DataFrame(x_new, columns=x.columns)
df_new
# Out:
#           Age  EstimatedSalary
# 0   -1.781797        -1.490046
# 1   -0.253587        -1.460681
# 2   -1.113206        -0.785290
# 3   -1.017692        -0.374182
# 4   -1.781797         0.183751
# ..        ...              ...
# 395  0.797057        -0.844019
# 396  1.274623        -1.372587
# 397  1.179110        -1.460681
# 398 -0.158074        -1.078938
# 399  1.083596        -0.990844
#
# [400 rows x 2 columns]

# %%
df_new.describe()
# Out:
#                 Age  EstimatedSalary
# count  4.000000e+02     4.000000e+02
# mean  -7.105427e-17    -1.776357e-17
# std    1.001252e+00     1.001252e+00
# min   -1.877311e+00    -1.607506e+00
# 25%   -7.550313e-01    -7.852897e-01
# 50%   -6.256110e-02     7.561451e-03
# 75%    7.970571e-01     5.361289e-01
# max    2.134241e+00     2.356750e+00

# %% [markdown]
# #### Cross Validation

# %%
df.shape
# Out:
# (400, 5)

# %%
# import the function
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df, random_state=0, test_size=0.2)

# %%
train.shape
# Out:
# (320, 5)

# %%
test.shape
# Out:
# (80, 5)

# %%
train
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 336  15664907    Male  58.0         144000.0          1
# 64   15605000  Female  59.0          83000.0          0
# 55   15649136  Female  24.0          55000.0          0
# 106  15706185  Female  26.0          35000.0          0
# 300  15736397  Female  58.0          38000.0          1
# ..        ...     ...   ...              ...        ...
# 323  15619465  Female  48.0          30000.0          1
# 192  15779581    Male  29.0          43000.0          0
# 117  15591433    Male  36.0          52000.0          0
# 47   15776348  Female  27.0          54000.0          0
# 172  15794661  Female  26.0         118000.0          0
#
# [320 rows x 5 columns]

# %%
# Separate the input and output variables 
x = df[['Age','EstimatedSalary']]  # input
y = df['Purchased']   # output

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)

# %%
x_train.shape
# Out:
# (300, 2)

# %%
x_test.shape
# Out:
# (100, 2)

# %%
y_train.shape
# Out:
# (300,)

# %%
y_test.shape
# Out:
# (100,)

# %%
x_train.iloc[200]
# Out:
# Age                   49.0
# EstimatedSalary    74000.0
# Name: 201, dtype: float64

# %%
y_train.iloc[200]
# Out:
# 0

# %% [markdown]
# #### Data Encoding

# %%
df = pd.read_csv("student-info.csv")

# %%
df.head()
# Out:
#    roll              name class  marks  age
# 0     1   Aditya Kulkarni    FY   85.5   15
# 1     2     Swapnil Joshi    FY   92.1   16
# 2     3  Aniket Deshpande    FY   78.3   16
# 3     4       Gauri Patil    FY   65.8   14
# 4     5      Rohan Sawant    FY   88.2   17

# %%
# Label encoding
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['name'] = le.fit_transform(df['name'])

# %%
df
# Out:
#     roll  name class  marks  age
# 0      1     1    FY   85.5   15
# 1      2    27    FY   92.1   16
# 2      3     3    FY   78.3   16
# 3      4     5    FY   65.8   14
# 4      5    18    FY   88.2   17
# 5      6    13    FY   72.9   13
# 6      7    23    FY   95.0   16
# 7      8    24    FY   58.6   14
# 8      9     9    FY   76.4   18
# 9     10    16    FY   89.7   15
# 10    11     2    SY   91.2   13
# 11    12    22    SY   68.5   17
# 12    13    12    SY   79.9   17
# 13    14    20    SY   83.1   15
# 14    15    10    SY   94.6   15
# 15    16    15    SY   61.3   14
# 16    17     0    SY   77.8   16
# 17    18    21    SY   82.0   18
# 18    19    17    SY   90.4   14
# 19    20     8    SY   73.7   16
# 20    21     4    TY   55.1   13
# 21    22    28    TY   66.9   17
# 22    23    25    TY   96.2   17
# 23    24     7    TY   71.5   15
# 24    25    14    TY   48.8   15
# 25    26    11    TY   84.3   14
# 26    27    19    TY   59.7   16
# ...

# %%
# one hot encoding 
df = pd.get_dummies(df)

# %%
df
# Out:
#     roll  name  marks  age  class_FY  class_SY  class_TY
# 0      1     1   85.5   15      True     False     False
# 1      2    27   92.1   16      True     False     False
# 2      3     3   78.3   16      True     False     False
# 3      4     5   65.8   14      True     False     False
# 4      5    18   88.2   17      True     False     False
# 5      6    13   72.9   13      True     False     False
# 6      7    23   95.0   16      True     False     False
# 7      8    24   58.6   14      True     False     False
# 8      9     9   76.4   18      True     False     False
# 9     10    16   89.7   15      True     False     False
# 10    11     2   91.2   13     False      True     False
# 11    12    22   68.5   17     False      True     False
# 12    13    12   79.9   17     False      True     False
# 13    14    20   83.1   15     False      True     False
# 14    15    10   94.6   15     False      True     False
# ...
