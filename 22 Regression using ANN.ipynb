# %% [markdown]
# #### Dataset

# %%
# BostonHousing.csv
# https://mitu.co.in/dataset

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets/BostonHousing.csv')

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %% [markdown]
# #### Separate the input and output variables

# %%
x = df.drop('medv', axis = 1)
y = df['medv']

# %% [markdown]
# #### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_scaled = scaler.fit_transform(x)

# %% [markdown]
# #### Cross Validation

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x_scaled, y, random_state=0)

# %%
x_train.shape
# Out:
# (379, 13)

# %% [markdown]
# #### Build the model

# %%
from keras.models import Sequential
from keras.layers import Dense, Input

# %%
model = Sequential()

model.add(Input((13,)))

model.add(Dense(16, activation='relu'))

model.add(Dense(8, activation='relu'))

model.add(Dense(1))

# %% [markdown]
# #### Compile the model

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %% [markdown]
# #### Train the model

# %%
model.fit(x_train, y_train, epochs=50, batch_size=1)
# Out:
# Epoch 1/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - loss: 12.1734 - mae: 2.4986
# Epoch 2/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.4113 - mae: 2.4444
# Epoch 3/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 11.6599 - mae: 2.2830
# Epoch 4/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 10.4881 - mae: 2.1753
# Epoch 5/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12.2247 - mae: 2.4345
# Epoch 6/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 8.0693 - mae: 2.0460
# Epoch 7/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 7.2097 - mae: 1.9355
# Epoch 8/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2227 - mae: 2.0863
# Epoch 9/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9895 - mae: 2.0630
# Epoch 10/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 11.6820 - mae: 2.3110
# Epoch 11/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3297 - mae: 2.1047
# Epoch 12/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6495 - mae: 2.1256
# Epoch 13/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.1320 - mae: 2.1239
# Epoch 14/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 11.3201 - mae: 2.3139
# Epoch 15/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4935 - mae: 1.9650
# Epoch 16/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 8.9181 - mae: 2.0012
# Epoch 17/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9054 - mae: 2.0474
# Epoch 18/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 7.1171 - mae: 1.9415
# Epoch 19/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 7.0630 - mae: 2.0139
# Epoch 20/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 6.5227 - mae: 1.9165
# Epoch 21/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8400 - mae: 2.0319
# Epoch 22/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.2035 - mae: 1.8718
# Epoch 23/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 7.0722 - mae: 1.9217
# Epoch 24/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 6.8109 - mae: 1.9198
# Epoch 25/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.7425 - mae: 1.9940
# Epoch 26/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0582 - mae: 2.0244
# Epoch 27/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 7.8130 - mae: 1.9615
# Epoch 28/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - loss: 5.5163 - mae: 1.7441
# Epoch 29/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.4005 - mae: 1.9917
# Epoch 30/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 6.7585 - mae: 1.9243
# Epoch 31/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 7.2717 - mae: 1.9344
# Epoch 32/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 7.6532 - mae: 1.8954
# Epoch 33/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 6.0450 - mae: 1.9224
# Epoch 34/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - loss: 5.4437 - mae: 1.7596
# Epoch 35/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2540 - mae: 1.6588
# Epoch 36/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - loss: 9.3717 - mae: 2.0840
# Epoch 37/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 5.6611 - mae: 1.7987
# Epoch 38/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4911 - mae: 1.6916
# Epoch 39/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0959 - mae: 1.9925
# Epoch 40/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 6.6464 - mae: 1.9134
# Epoch 41/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 7.0751 - mae: 1.9446
# Epoch 42/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 5.7824 - mae: 1.7295
# Epoch 43/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.1405 - mae: 1.8027
# Epoch 44/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 8.0109 - mae: 2.0614
# Epoch 45/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.2328 - mae: 1.8585
# Epoch 46/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 4.8257 - mae: 1.6076
# Epoch 47/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.0120 - mae: 1.8014
# Epoch 48/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 5.2928 - mae: 1.6582
# Epoch 49/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - loss: 5.5060 - mae: 1.7870
# Epoch 50/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - loss: 6.2915 - mae: 1.8397

# %%
model.evaluate(x_test, y_test, batch_size=1);
# Out:
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 30.6097 - mae: 3.2666

# %%
new = x.iloc[100,:]

# %%
new_scaled = scaler.transform([new])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
model.predict(new_scaled)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# array([[22.562826]], dtype=float32)
